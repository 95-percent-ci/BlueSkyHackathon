# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
pd.options.plotting.backend = "plotly"

# %%
data = pd.read_csv("Data/AirQuality.csv", parse_dates=['Date'], index_col='Date')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9357 entries, 2004-03-10 18:00:00 to 2005-04-04 14:00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    9357 non-null   object
#  1   CO(GT)  9357 non-null   float64
#  2   T       9357 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 292.4+ KB

# %%
data
# Out:
#                          Time  CO(GT)       T
# Date
# 2004-03-10 18:00:00  18:00:00     2.6  13.600
# 2004-03-10 19:00:00  19:00:00     2.0  13.300
# 2004-03-10 20:00:00  20:00:00     2.2  11.900
# 2004-03-10 21:00:00  21:00:00     2.2  11.000
# 2004-03-10 22:00:00  22:00:00     1.6  11.150
# ...                       ...     ...     ...
# 2005-04-04 10:00:00  10:00:00     3.1  21.850
# 2005-04-04 11:00:00  11:00:00     2.4  24.325
# 2005-04-04 12:00:00  12:00:00     2.4  26.900
# 2005-04-04 13:00:00  13:00:00     2.1  28.325
# 2005-04-04 14:00:00  14:00:00     2.2  28.500
#
# [9357 rows x 3 columns]

# %%
train_ts = ['2004-03-11', '2004-03-17']

# %%
test_ts = ['2004-03-18', '2004-03-24']

# %%
tr_data = data.loc[train_ts[0]:train_ts[1]]

# %%
test_data = data.loc[test_ts[0]:test_ts[1]]

# %%
# Replacing Outliers with nan
tr_data['CO(GT)'].replace({-200:np.nan}, inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py:4509: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Visualization

# %%
tr_data['hour'] = tr_data.index.hour
# Out:
# <ipython-input-11-bff267465e81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr_data['hour'] = tr_data.index.hour

# %%
tr_data[["T", "CO(GT)"]].plot()
# Out:
# <div>                            <div id="7632a839-0cf0-497e-8906-2ac66fd77a9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7632a839-0cf0-497e-8906-2ac66fd77a9d")) {                    Plotly.newPlot(                        "7632a839-0cf0-497e-8906-2ac66fd77a9d",                        [{"hovertemplate": "variable=T<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "T", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "T", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2004-03-11T00:00:00", "2004-03-11T01:00:00", "2004-03-11T02:00:00", "2004-03-11T03:00:00", "2004-03-11T04:00:00", "2004-03-11T05:00:00", "2004-03-11T06:00:00", "2004-03-11T07:00:00", "2004-03-11T08:00:00", "2004-03-11T09:00:00", "
# ...
